# %% [markdown]
# ## Bike Sharing Demand for Capital Bikeshare in Washington D.C.

# %% [markdown]
# ## Part 1: Clean the dataset and create graphs to explore the trend

# %%
#Ignoring all the warnings that come
import warnings
warnings.filterwarnings('ignore')

#Import libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import seaborn as sns 
from sklearn.cross_validation import train_test_split
from datetime import datetime
import statsmodels.formula.api as sm

#Load Data with pandas, and parse the first column into datetime

url = "https://drive.google.com/uc?export=download&id=1sqr3X9W1yRjQLMbaf88TuARecS4wtfft"  #Public URL for the dataset
train = pd.read_csv(url, parse_dates=[0])

# %% [markdown]
# # Data Fields
#
# - Datetime: hourly date + timestamp
# - Season: 1 = spring, 2 = summer, 3 = fall, 4 = winter
# - Holiday: whether the day is considered a holiday
# - Workingday: whether the day is neither a weekend nor holiday
# - Weather:
#           1: Clear, Few clouds, Partly cloudy, Partly cloudy
#           2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
#           3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#           4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# - Temp: temperature in Celsius
# - Atemp: "feels like" temperature in Celsius
# - Humidity: relative humidity
# - Windspeed: wind speed
# - Casual: number of non-registered user rentals initiated
# - Registered: number of registered user rentals initiated
# - Count: number of total rentals

# %%
#process the timestamp into year, month, hour and weekday
temp = pd.DatetimeIndex(train['datetime'])
train['year'] = temp.year
train['month'] = temp.month
train['hour'] = temp.hour
train['weekday'] = temp.weekday
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  hour  weekday
# 0        81        0.0       3          13     16  2011      1     0        5
# 1        80        0.0       8          32     40  2011      1     1        5
# 2        80        0.0       5          27     32  2011      1     2        5
# 3        75        0.0       3          10     13  2011      1     3        5
# 4        75        0.0       0           1      1  2011      1     4        5

# %%
#Define features vector

features = ['season', 'holiday', 'workingday', 'weather',
        'temp', 'atemp', 'humidity', 'windspeed', 'year',
         'month', 'weekday', 'hour']

# %%
#plot the histogram of rental count and log of rental count
rentals = train['count']

f, (ax1, ax2) = plt.subplots(1, 2)
ax1.hist((rentals))
ax1.set_title('Histogram of rentals')
ax2.hist(np.log(rentals))
ax2.set_title('Histogram of log(rentals)')
# Out:
# Text(0.5,1,'Histogram of log(rentals)')

# %% [markdown]
# The rentals variable is distributed to be skewed to the right; while log(rentals) variable is distributed to be skewed to the left.

# %% [markdown]
# # Data Cleaning
#
# Two steps done to clean the data set:
#
# 1) As we can see the rentals distribution is skewed, as a first measure of data cleaning we remved the outliers from the dataset. Outliers were considered to be those values of rentals which were greater than I3+1.5*IQR.
#
# 2) Since the windspeed column has some zeros values associated with it, so we removed the rows where windspeed=0

# %%
rentals_describe = train['count'].describe()

IQR = rentals_describe['75%'] - rentals_describe['25%']
outlier = rentals_describe['75%'] + 1.5*IQR

train = train[train['count']<=outlier]

# Since we see that windspeed not much correlation with the rentals count and it has lot of zeros\
# so we can first anlyse the results by dropping the windspeed column

train = train[(train['windspeed'] != 0)]

# %%
#grouping by season, plot the box plot
season_group= (train.groupby("season"))["count"].sum()
season_group.reset_index(name="total_rentals")
sns.boxplot(y='count',x='season',data=train,width=0.5,palette="colorblind")
plt.show()

# %% [markdown]
# The count is lowest in spring and highest in fall. However, there are a lot of outliers in Winter and Spring.

# %%
#grouping by weekday, plot the box plot
weekday_group= (train.groupby("weekday"))["count"].sum()
weekday_group.reset_index(name="total_rentals")
sns.boxplot(y='count',x='weekday',data=train,width=0.5,palette="colorblind")
#deep,muted,pastel,bright,dark,colorblind,Blues,BuGn_r,GnBu_d
plt.show()

# %%
#seeing the difference between workday and non-workday
wd_group= (train.groupby("workingday"))["count"].sum()
wd_group.reset_index(name="total_rentals")
sns.boxplot(y='count',x='workingday',data=train,width=0.5,palette="colorblind")
plt.show()

# %% [markdown]
# Count is pretty constant throughout the week. However, there are a lot of outliers from Monday to Friday and fewer during weekend.

# %%
#group by season and see the difference between holiday and non-holiday
sns.boxplot(y='count',x='holiday',data=train,hue="season",width=0.5,palette="colorblind")

# %%
#seeing the difference between holiday and non-holiday
holiday_group= (train.groupby("holiday"))["count"].sum()
holiday_group.reset_index(name="total_rentals")
sns.boxplot(y='count',x='holiday',data=train,width=0.5,palette="colorblind")
plt.show()

# %% [markdown]
# There is not much difference between holiday and non-holiday, except that there are outliers for non-holiday group.

# %%
#grouping by weather and plot the box plot
weather_group= (train.groupby("weather"))["count"].sum()
weather_group.reset_index(name="total_rentals")
sns.boxplot(y='count',x='weather',data=train,width=0.5,palette="colorblind")
plt.show()

# %% [markdown]
# The number of bikes rented decreases as the weather gets more severe.

# %%
#group by season and see the difference between the 2 years
sns.boxplot(y='count',x='year',data=train,hue='season',width=0.5,palette="colorblind")

# %%
#annual change
year_group= (train.groupby("year"))["count"].sum()
year_group.reset_index(name="total_rentals")
sns.boxplot(y='count',x='year',data=train,width=0.5,palette="colorblind")
plt.show()

# %% [markdown]
# There are more bikes rented in 2012 than in 2011, which may indicate that there is an impact of time on the dependent variable.

# %%
#monthly change
month_group= (train.groupby("month"))["count"].sum()
month_group.reset_index(name="total_rentals")
sns.boxplot(y='count',x='month',data=train,width=0.5,palette="colorblind")
plt.show()

# %% [markdown]
# The change according to month follows the trend found according to season.

# %%
#hourly change expressed in bar graph
hour_group= (train.groupby("hour"))["count"].sum()
hour_group.reset_index(name="total_rentals")
sns.barplot(y='count',x='hour',data=train,palette="colorblind")
plt.show()

# %% [markdown]
# The rush hour is 8 o'clock in the morning and 5 to 6 o'clock in the afternoon.

# %%
#see if there is relation between windspeed and count
sns.jointplot(y='count',x='windspeed',data=train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ## Part 2: Find correlation between variables for the regression

# %%
corr = train.corr()
corr.style.background_gradient().set_precision(1)
# Out:
# <style  type="text/css" >
#     #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow0_col0 {
#             background-color:  #023858;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow0_col1 {
#             background-color:  #d7d6e9;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow0_col2 {
#             background-color:  #99b8d8;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow0_col3 {
#             background-color:  #e7e3f0;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow0_col4 {
#             background-color:  #bcc7e1;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow0_col5 {
#             background-color:  #b5c4df;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow0_col6 {
#             background-color:  #a1bbda;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow0_col7 {
#             background-color:  #e8e4f0;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow0_col8 {
#             background-color:  #b5c4df;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow0_col9 {
#             background-color:  #afc1dd;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow0_col10 {
#             background-color:  #a7bddb;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow0_col11 {
#             background-color:  #f7f0f7;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow0_col12 {
#             background-color:  #023e62;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow0_col13 {
#             background-color:  #dad9ea;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow0_col14 {
#             background-color:  #97b7d7;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow1_col0 {
#             background-color:  #e7e3f0;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow1_col1 {
#             background-color:  #023858;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow1_col2 {
#             background-color:  #cacee5;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow1_col3 {
#             background-color:  #ece7f2;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow1_col4 {
#             background-color:  #faf2f8;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow1_col5 {
#             background-color:  #f7f0f7;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow1_col6 {
#             background-color:  #d1d2e6;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow1_col7 {
#             background-color:  #cdd0e5;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow1_col8 {
#             background-color:  #c6cce3;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow1_col9 {
#             background-color:  #dbdaeb;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow1_col10 {
#             background-color:  #d2d3e7;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow1_col11 {
#             background-color:  #f3edf5;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow1_col12 {
#             background-color:  #ece7f2;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow1_col13 {
#             background-color:  #d9d8ea;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow1_col14 {
#             background-color:  #bfc9e1;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow2_col0 {
#             background-color:  #eee8f3;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow2_col1 {
#             background-color:  #fff7fb;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow2_col2 {
#             background-color:  #023858;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow2_col3 {
#             background-color:  #e7e3f0;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow2_col4 {
#             background-color:  #f4eef6;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow2_col5 {
#             background-color:  #f2ecf5;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow2_col6 {
#             background-color:  #d3d4e7;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow2_col7 {
#             background-color:  #cacee5;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow2_col8 {
#             background-color:  #fff7fb;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow2_col9 {
#             background-color:  #c4cbe3;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow2_col10 {
#             background-color:  #d7d6e9;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow2_col11 {
#             background-color:  #f8f1f8;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow2_col12 {
#             background-color:  #ece7f2;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow2_col13 {
#             background-color:  #dad9ea;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow2_col14 {
#             background-color:  #fff7fb;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow3_col0 {
#             background-color:  #e8e4f0;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow3_col1 {
#             background-color:  #dbdaeb;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow3_col2 {
#             background-color:  #8fb4d6;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow3_col3 {
#             background-color:  #023858;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow3_col4 {
#             background-color:  #fff7fb;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow3_col5 {
#             background-color:  #fcf4fa;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow3_col6 {
#             background-color:  #529bc7;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow3_col7 {
#             background-color:  #d2d3e7;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow3_col8 {
#             background-color:  #e8e4f0;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow3_col9 {
#             background-color:  #efe9f3;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow3_col10 {
#             background-color:  #ece7f2;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow3_col11 {
#             background-color:  #f9f2f8;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow3_col12 {
#             background-color:  #e7e3f0;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow3_col13 {
#             background-color:  #e0dded;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow3_col14 {
#             background-color:  #a1bbda;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow4_col0 {
#             background-color:  #a9bfdc;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow4_col1 {
#             background-color:  #dedcec;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow4_col2 {
#             background-color:  #8fb4d6;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow4_col3 {
#             background-color:  #f3edf5;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow4_col4 {
#             background-color:  #023858;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow4_col5 {
#             background-color:  #023b5d;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow4_col6 {
#             background-color:  #d5d5e8;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow4_col7 {
#             background-color:  #d8d7e9;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow4_col8 {
#             background-color:  #4094c3;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow4_col9 {
#             background-color:  #88b1d4;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow4_col10 {
#             background-color:  #62a2cb;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow4_col11 {
#             background-color:  #f2ecf5;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow4_col12 {
#             background-color:  #a8bedc;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow4_col13 {
#             background-color:  #bbc7e0;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow4_col14 {
#             background-color:  #9fbad9;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7frow5_col0 {
#             background-color:  #a8bedc;
#         }    #T_96544c26_9114_11e8_ab41_5c5f67a84a7fro

# %% [markdown]
# hour and temp has strongest correlation with the count of bikes. But hour and temp also have significant correlation with each other.

# %%
dataY = train['count'] #target variable
dataX = train.drop(columns=['count'],axis=1) #independent variables

# %%
# create training and testing vars
X_train, X_test, y_train, y_test = train_test_split(train,dataY, test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
X_train.head()

#convert variables into categories
X_train['season'] = X_train['season'].astype('category')
X_train['hour'] = X_train['hour'].astype('category')
X_train['weekday'] = X_train['weekday'].astype('category')
X_train['month'] = X_train['month'].astype('category')
# Out:
# (8708, 16) (8708,)
# (2178, 16) (2178,)

# %% [markdown]
# ## Part 3: Regression Analysis

# %%
#1st try of regression with all the variables
model_fit = sm.ols(formula="count ~ hour + season + month + weather + temp +windspeed", data=X_train).fit()
print(model_fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.624
# Model:                            OLS   Adj. R-squared:                  0.622
# Method:                 Least Squares   F-statistic:                     388.7
# Date:                Thu, 26 Jul 2018   Prob (F-statistic):               0.00
# Time:                        17:58:35   Log-Likelihood:                -53381.
# No. Observations:                8708   AIC:                         1.068e+05
# Df Residuals:                    8670   BIC:                         1.071e+05
# Df Model:                          37
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     -54.3689      8.411     -6.464      0.000     -70.856     -37.881
# hour[T.1]     -18.6151      8.297     -2.244      0.025     -34.880      -2.350
# hour[T.2]     -31.3795      8.410     -3.731      0.000     -47.865     -14.894
# hour[T.3]     -42.6260      8.424     -5.060      0.000     -59.140     -26.112
# hour[T.4]     -44.5683      8.356     -5.333      0.000     -60.949     -28.188
# hour[T.5]     -25.9176      8.471     -3.060      0.002     -42.522      -9.313
# hour[T.6]      31.9063      8.324      3.833      0.000      15.589      48.223
# hour[T.7]     165.7862      8.355     19.843      0.000     149.408     182.164
# hour[T.8]     312.7365      8.380     37.318      0.000     296.309     329.164
# hour[T.9]     166.3236      8.311     20.013      0.000     150.032     182.615
# hour[T.10]    110.5632      8.362     13.221      0.000      94.171     126.956
# hour[T.11]    140.2575      8.325     16.847      0.000     123.938     156.577
# hour[T.12]    183.3987      8.398     21.837      0.000     166.936     199.862
# hour[T.13]    178.7936      8.428     21.215      0.000     162.273     195.314
# hour[T.14]    160.4573      8.464     18.958      0.000     143.867     177.048
# hour[T.15]    173.5185      8.463     20.502      0.000     156.928     190.109
# hour[T.16]    231.3076      8.531     27.115      0.000     214.585     248.030
# hour[T.17]    387.0858      8.420     45.972      0.000     370.581     403.591
# hour[T.18]    354.4698      8.430     42.048      0.000     337.945     370.995
# hour[T.19]    244.3192      8.320     29.367      0.000     228.011     260.628
# hour[T.20]    162.0761      8.365     19.375      0.000     145.678     178.474
# hour[T.21]    108.7598      8.375     12.986      0.000      92.343     125.177
# hour[T.22]     69.3339      8.293      8.361      0.000      53.078      85.590
# hour[T.23]     32.9253      8.243      3.995      0.000      16.768      49.083
# season[T.2]    28.2247      5.051      5.587      0.000      18.323      38.127
# season[T.3]     9.2371      6.293      1.468      0.142      -3.098      21.572
# season[T.4]    49.0221      4.091     11.983      0.000      41.003      57.041
# month[T.2]      8.9980      5.961      1.509      0.131      -2.688      20.684
# month[T.3]     19.1738      6.274      3.056      0.002       6.876      31.472
# month[T.4]      8.7555      3.596      2.435      0.015       1.707      15.804
# month[T.5]     15.9881      3.761      4.251      0.000       8.616      23.360
# month[T.6]      3.4811      4.493      0.775      0.439      -5.327      12.289
# month[T.7]    -14.8885      4.348     -3.424      0.001     -23.411      -6.366
# month[T.8]     -5.1341      4.116     -1.248      0.212     -13.202       2.933
# month[T.9]     29.2598      3.687      7.937      0.000      22.033      36.487
# month[T.10]    17.6090      4.207      4.186      0.000       9.363      25.855
# month[T.11]    18.3914      3.605      5.102      0.000      11.325      25.458
# month[T.12]    13.0217      3.553      3.665      0.000       6.057      19.986
# weather       -34.4930      1.911    -18.051      0.000     -38.239     -30.747
# temp            7.0674      0.360     19.640      0.000       6.362       7.773
# windspeed      -0.5672      0.154     -3.683      0.000      -0.869      -0.265
# ==============================================================================
# Omnibus:                      887.203   Durbin-Watson:                   1.959
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1845.651
# Skew:                           0.651   Prob(JB):                         0.00
# Kurtosis:                       4.841   Cond. No.                     8.42e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.84e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# Adj. R squared is 0.62 here. Some random variables have high p value or having an insignificant linear relationship to the number of bike get rented

# %%
# fitted values (need a constant term for intercept)
model_fitted_y = model_fit.fittedvalues

# model residuals
model_residuals = model_fit.resid

# normalized residuals
model_norm_residuals = model_fit.get_influence().resid_studentized_internal

# absolute squared normalized residuals
model_norm_residuals_abs_sqrt = np.sqrt(np.abs(model_norm_residuals))

# absolute residuals
model_abs_resid = np.abs(model_residuals)

# %%
# plot the residuals
residualplot = plt.figure(1)
residualplot.set_figheight(8)
residualplot.set_figwidth(12)

residualplot.axes[0] = sns.residplot(model_fitted_y, y_train, 
                          lowess=True, 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

residualplot.axes[0].set_title('Residuals vs Fitted')
residualplot.axes[0].set_xlabel('Fitted values')
residualplot.axes[0].set_ylabel('Residuals')
# Out:
# Text(0,0.5,'Residuals')

# %% [markdown]
# Seeing heteroskedasticity in the residual plot. The pattern in the residuals plot indicate that this linear regression model is not good.

# %%
#plot the qq plot to find the residule have normal distribution
from statsmodels.graphics.gofplots import ProbPlot

QQ = ProbPlot(model_norm_residuals)
plot_lm_2 = QQ.qqplot(line='45', alpha=0.5, color='#4C72B0', lw=1)

plot_lm_2.set_figheight(8)
plot_lm_2.set_figwidth(12)

plot_lm_2.axes[0].set_title('Normal Q-Q')
plot_lm_2.axes[0].set_xlabel('Theoretical Quantiles')
plot_lm_2.axes[0].set_ylabel('Standardized Residuals');

# %% [markdown]
# Residuals are not normal distributed since the blue dots are not lying on the straight line. We can conclude that this is not a fitted model.
#
# To improve the model, we next fit the model by taking lograithmic of number of rentals as the dependent variable.

# %%
#2nd try of regression analysis by changing the dependent variable to log
X_train['logCount'] = np.log(X_train['count'])
y_train = X_train['logCount']

X_test['logCount'] = np.log(X_test['count'])
y_test = X_test['logCount']

model_fit = sm.ols(formula="logCount ~ hour + season + month + weather + temp +windspeed", data=X_train).fit()
#print(model_fit.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               logCount   R-squared:                       0.796
# Model:                            OLS   Adj. R-squared:                  0.795
# Method:                 Least Squares   F-statistic:                     915.7
# Date:                Thu, 26 Jul 2018   Prob (F-statistic):               0.00
# Time:                        17:59:02   Log-Likelihood:                -8888.4
# No. Observations:                8708   AIC:                         1.785e+04
# Df Residuals:                    8670   BIC:                         1.812e+04
# Df Model:                          37
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       2.9598      0.051     58.262      0.000       2.860       3.059
# hour[T.1]      -0.6427      0.050    -12.825      0.000      -0.741      -0.544
# hour[T.2]      -1.2127      0.051    -23.874      0.000      -1.312      -1.113
# hour[T.3]      -1.8136      0.051    -35.644      0.000      -1.913      -1.714
# hour[T.4]      -2.0992      0.050    -41.591      0.000      -2.198      -2.000
# hour[T.5]      -1.0232      0.051    -19.999      0.000      -1.123      -0.923
# hour[T.6]       0.2358      0.050      4.689      0.000       0.137       0.334
# hour[T.7]       1.2132      0.050     24.041      0.000       1.114       1.312
# hour[T.8]       1.8833      0.051     37.208      0.000       1.784       1.983
# hour[T.9]       1.5711      0.050     31.299      0.000       1.473       1.669
# hour[T.10]      1.2211      0.051     24.178      0.000       1.122       1.320
# hour[T.11]      1.3587      0.050     27.020      0.000       1.260       1.457
# hour[T.12]      1.5512      0.051     30.581      0.000       1.452       1.651
# hour[T.13]      1.5311      0.051     30.079      0.000       1.431       1.631
# hour[T.14]      1.4319      0.051     28.011      0.000       1.332       1.532
# hour[T.15]      1.4813      0.051     28.978      0.000       1.381       1.581
# hour[T.16]      1.7269      0.052     33.517      0.000       1.626       1.828
# hour[T.17]      2.1353      0.051     41.987      0.000       2.036       2.235
# hour[T.18]      2.0740      0.051     40.734      0.000       1.974       2.174
# hour[T.19]      1.7832      0.050     35.489      0.000       1.685       1.882
# hour[T.20]      1.4903      0.051     29.497      0.000       1.391       1.589
# hour[T.21]      1.2155      0.051     24.030      0.000       1.116       1.315
# hour[T.22]      0.9539      0.050     19.045      0.000       0.856       1.052
# hour[T.23]      0.5618      0.050     11.284      0.000       0.464       0.659
# season[T.2]     0.3331      0.031     10.918      0.000       0.273       0.393
# season[T.3]     0.2596      0.038      6.830      0.000       0.185       0.334
# season[T.4]     0.4840      0.025     19.589      0.000       0.436       0.532
# month[T.2]      0.1382      0.036      3.838      0.000       0.068       0.209
# month[T.3]      0.1817      0.038      4.795      0.000       0.107       0.256
# month[T.4]      0.0262      0.022      1.205      0.228      -0.016       0.069
# month[T.5]      0.2021      0.023      8.898      0.000       0.158       0.247
# month[T.6]      0.1048      0.027      3.862      0.000       0.052       0.158
# month[T.7]      0.0286      0.026      1.091      0.275      -0.023       0.080
# month[T.8]      0.0481      0.025      1.936      0.053      -0.001       0.097
# month[T.9]      0.1828      0.022      8.210      0.000       0.139       0.226
# month[T.10]     0.1352      0.025      5.321      0.000       0.085       0.185
# month[T.11]     0.1891      0.022      8.684      0.000       0.146       0.232
# month[T.12]     0.1597      0.021      7.444      0.000       0.118       0.202
# weather        -0.2356      0.012    -20.416      0.000      -0.258      -0.213
# temp            0.0400      0.002     18.407      0.000       0.036       0.044
# windspeed      -0.0045      0.001     -4.866      0.000      -0.006      -0.003
# ==============================================================================
# Omnibus:                      531.122   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1040.484
# Skew:                          -0.436   Prob(JB):                    1.15e-226
# Kurtosis:                       4.452   Cond. No.                     8.42e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.84e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# We got higher value in Adj. R squared (=0.79). However, there are still some month variables that have insignificant impact on the dependent variable.

# %%
# fitted values (need a constant term for intercept)
model_fitted_y = model_fit.fittedvalues

# model residuals
model_residuals = model_fit.resid

# normalized residuals
model_norm_residuals = model_fit.get_influence().resid_studentized_internal

# absolute squared normalized residuals
model_norm_residuals_abs_sqrt = np.sqrt(np.abs(model_norm_residuals))

# absolute residuals
model_abs_resid = np.abs(model_residuals)

# %%
#conduct the residule plot
residualplot = plt.figure(1)
residualplot.set_figheight(8)
residualplot.set_figwidth(12)

residualplot.axes[0] = sns.residplot(model_fitted_y, y_train, 
                          lowess=True, 
                          scatter_kws={'alpha': 0.5}, 
                          line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

residualplot.axes[0].set_title('Residuals vs Fitted')
residualplot.axes[0].set_xlabel('Fitted values')
residualplot.axes[0].set_ylabel('Residuals')
# Out:
# Text(0,0.5,'Residuals')

# %% [markdown]
# It can be seen in the above graph that this graph has a less uniform pattern than the previous plot.

# %%
#plot the qq plot
from statsmodels.graphics.gofplots import ProbPlot

QQ = ProbPlot(model_norm_residuals)
plot_lm_2 = QQ.qqplot(line='45', alpha=0.5, color='#4C72B0', lw=1)

plot_lm_2.set_figheight(8)
plot_lm_2.set_figwidth(12)

plot_lm_2.axes[0].set_title('Normal Q-Q')
plot_lm_2.axes[0].set_xlabel('Theoretical Quantiles')
plot_lm_2.axes[0].set_ylabel('Standardized Residuals');

# %% [markdown]
# Seeing a better patten in the residual plot. The points are more normal distributed comparing to that in the last model.

# %%
#Root Mean Squared Logarithmic Error
def rmsle(prediction, actual):
    log1 = np.nan_to_num(np.array([v for v in prediction]))
    log2 = np.nan_to_num(np.array([v for v in actual]))
    calc = (log1 - log2) ** 2
    return np.sqrt(np.mean(calc))

# %%
#Performing the predictions using the fitted model and computing MSE

ypred = model_fit.predict(X_test)
predictions = ypred.values

i=0
for v in predictions:
    if predictions[i]<0:
        predictions[i] = 0
    i = i+1    

RMSLE = rmsle(predictions,y_test)
print(" The Mean Squared error for this model is:",RMSLE)
# Out:
#  The Mean Squared error for this model is: 0.6886047979058273

# %%
# check the model in the test data
plt.figure(figsize=(5, 5))
plt.scatter(predictions,y_test)
plt.legend(["DataPoints"])
plt.plot( [0,8],[0,8], color='red')
plt.legend(["AccuracyLine","DataPoints"])
plt.xlabel('Predictions')
plt.ylabel('test_y')
plt.title('Linear Regression Model')

train.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 5  2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 10 2011-01-01 10:00:00       1        0           0        1  15.58  19.695
# 11 2011-01-01 11:00:00       1        0           0        1  14.76  16.665
# 12 2011-01-01 12:00:00       1        0           0        1  17.22  21.210
# 13 2011-01-01 13:00:00       1        0           0        2  18.86  22.725
#
#     humidity  windspeed  casual  registered  count  year  month  hour  weekday
# 5         75     6.0032       0           1      1  2011      1     5        5
# 10        76    16.9979      12          24     36  2011      1    10        5
# 11        81    19.0012      26          30     56  2011      1    11        5
# 12        77    19.0012      29          55     84  2011      1    12        5
# 13        72    19.9995      47          47     94  2011      1    13        5

# %% [markdown]
# As in the graph, we can say that the model fit pretty well.

# %% [markdown]
# ## Part 4: Time Series Consideration in the regression analysis

# %% [markdown]
# As a further extension we also include the timeseries impact on the rentals, since the number of rentals increases month by month.
#
# The way we do this is make the month column grow linearly over each month.

# %%
train["month"] = train["datetime"].dt.month

def timeseries_month(df):
    year = df.year
    month = df.month
    if year>2011:
        month = df.month+ 12*(year-2011)
    
    return month

train['month'] = train.apply(timeseries_month,axis=1)
X_train['month'] = X_train.apply(timeseries_month,axis=1)
X_test['month'] = X_test.apply(timeseries_month,axis=1)

# %%
X_train['logCount'] = np.log(X_train['count'])
y_train = X_train['logCount']

X_test['logCount'] = np.log(X_test['count'])
y_test = X_test['logCount']

model_fit = sm.ols(formula="logCount ~ hour + season + month + weather + temp +windspeed", data=X_train).fit_regularized()
print(model_fit.params)
# Out:
# Intercept      3.182026
# hour[T.1]     -0.715472
# hour[T.2]     -1.276338
# hour[T.3]     -1.884105
# hour[T.4]     -2.172999
# hour[T.5]     -1.100023
# hour[T.6]      0.206658
# hour[T.7]      1.087827
# hour[T.8]      1.726928
# hour[T.9]      1.512011
# hour[T.10]     1.217582
# hour[T.11]     1.375192
# hour[T.12]     1.546874
# hour[T.13]     1.554219
# hour[T.14]     1.430747
# hour[T.15]     1.523989
# hour[T.16]     1.776688
# hour[T.17]     2.136142
# hour[T.18]     2.038145
# hour[T.19]     1.766966
# hour[T.20]     1.441455
# hour[T.21]     1.187056
# hour[T.22]     0.918300
# hour[T.23]     0.479426
# season[T.2]    0.462930
# season[T.3]    0.404905
# season[T.4]    0.408821
# month          0.020598
# weather       -0.248099
# temp           0.020812
# windspeed     -0.010421
# dtype: float64

# %% [markdown]
# The Adj. R squared is 0.823, which is improved from the last model. We now dont have any insignificant variables as there is no high p value. It is better to consider time change in our model.

# %%
ypred = model_fit.predict(X_test)
predictions = ypred.values

i=0
for v in predictions:
    if predictions[i]<0:
        predictions[i] = 0
    i = i+1    

RMSLE = rmsle(predictions,y_test)
print("RMSLE:",RMSLE)

#test the model in the test data
plt.figure(figsize=(5, 5))
plt.scatter(predictions,y_test)
plt.legend(["DataPoints"])
plt.plot( [0,8],[0,8], color='red')
plt.legend(["AccuracyLine","DataPoints"])
plt.xlabel('Predictions')
plt.ylabel('test_y')
plt.title('Linear Regression Model')
plt.savefig("Overall_Regression_Model")
# Out:
# RMSLE: 0.6368601904175144

# %%
from sklearn.linear_model import Ridge
import numpy as np
n_samples, n_features = 10, 5
np.random.seed(0)
y = np.random.randn(n_samples)
X = np.random.randn(n_samples, n_features)
clf = Ridge(alpha=1.0)
clf.fit(X, y) 
Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
      normalize=False, random_state=None, solver='auto', tol=0.001)
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %% [markdown]
# As in the graph, we can say that the model fit pretty well.

# %% [markdown]
# ## Part 5: Analyzing Number of Observations on the run time of regression

# %% [markdown]
# Since the number of rows in the dataset is only about 10000, for analyzing the time taken for regression what we do is concat the dataset to form double, quadraple and even bigger datasets.
#
# We then see how time taken for the regression changes according to the increase in data size

# %%
duplicity = [2,4,6,8,16,32,64]  #Duplicity factor for dataset
time_taken=[]

for dup in duplicity:
    duplist = []
    for i in range(dup):
        duplist.append(X_train)
    result = pd.concat(duplist)
    time1 = time.time()
    model_fit = sm.ols(formula="logCount ~ hour + season + month + weather + temp +windspeed", data=result).fit()
    time2 = time.time()
    time_taken.append(time2-time1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-2b4d8058d983> in <module>()
#       7         duplist.append(X_train)
#       8     result = pd.concat(duplist)
# ----> 9     time1 = time.time()
#      10     model_fit = sm.ols(formula="logCount ~ hour + season + month + weather + temp +windspeed", data=result).fit()
#      11     time2 = time.time()
#
# NameError: name 'time' is not defined

# %%
plt.figure(figsize=(5, 5))
plt.plot(duplicity,time_taken)
plt.xlabel('Data Size increase Factor')
plt.ylabel('Time taken for regression (in seconds)')
plt.title('Linear Regression Model')

# %% [markdown]
# If the dataset increase its size (currently by duplicating the factors of dataset), the time taken for regression will increase.
